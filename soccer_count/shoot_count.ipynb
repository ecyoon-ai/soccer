# %%
# install necessary packages for computer vision and deep learning.
# !pip install opencv-contrib-python==4.9.0.80  # Install OpenCV for image and video processing (with extra modules)
# !pip install opencv-python==4.9.0.80          # Standard OpenCV package
# !pip install opencv-python-headless==4.9.0.80 # OpenCV version for servers (no display GUI)

# Install Ultralytics, the library for YOLO models
# !pip install ultralytics

# Force numpy to version 1.26.4 to avoid conflicts
# !pip install numpy==1.26.4 --force-reinstall
# Out:
# Collecting opencv-contrib-python==4.9.0.80
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python==4.9.0.80) (2.0.2)
# Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 MB 10.5 MB/s eta 0:00:00
# Installing collected packages: opencv-contrib-python
#   Attempting uninstall: opencv-contrib-python
#     Found existing installation: opencv-contrib-python 4.11.0.86
#     Uninstalling opencv-contrib-python-4.11.0.86:
#       Successfully uninstalled opencv-contrib-python-4.11.0.86
# Successfully installed opencv-contrib-python-4.9.0.80
# Collecting opencv-python==4.9.0.80
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python==4.9.0.80) (2.0.2)
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 16.6 MB/s eta 0:00:00
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
# Successfully installed opencv-python-4.9.0.80
# Collecting opencv-python-headless==4.9.0.80
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless==4.9.0.80) (2.0.2)
# Downloading opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 10.8 MB/s eta 0:00:00
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
# Successfully installed opencv-python-headless-4.9.0.80
# Collecting ultralytics
#   Downloading ultralytics-8.3.143-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.143-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 62.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.143 ultralytics-thop-2.0.14
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 96.3 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
! kill -9 $(ps -A | grep python | awk '{print $1}')

# %%
import cv2
import numpy as np
from collections import defaultdict, deque
import os
from ultralytics import YOLO
import datetime

# %%
def calculate_angle(p1, p2, p3):
    """
    Calculate the angle between three points (p1-p2-p3) in degrees.

    Args:
        p1, p2, p3: NumPy arrays representing coordinates of three points.
    Returns:
        Angle in degrees.
    """
    v1 = p1 - p2  # Vector from p2 to p1
    v2 = p3 - p2  # Vector from p2 to p3
    cosine_angle = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))  # Cosine of angle
    cosine_angle = np.clip(cosine_angle, -1.0, 1.0)  # Avoid numerical errors
    return np.degrees(np.arccos(cosine_angle))  # Convert to degrees

def analyze_soccer_video(input_video, output_video):
    """
    Analyze a soccer video to detect and count shots based on player pose and ball position.

    Args:
        input_video: Path to the input video file.
        output_video: Path to save the output video with annotations.
    """
    # Load YOLO models for pose and ball detection
    pose_detector = YOLO("/content/drive/MyDrive/Colab Notebooks/soccer_prj/soccer/yolo11x-pose.pt")
    ball_detector = YOLO("/content/drive/MyDrive/Colab Notebooks/soccer_prj/soccer/soccer_ball.pt")

    # Open the input video
    video_reader = cv2.VideoCapture(input_video)
    if not video_reader.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties
    fps = video_reader.get(cv2.CAP_PROP_FPS)  # Frames per second
    width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))  # Video width
    height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))  # Video height
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Video codec
    video_writer = cv2.VideoWriter(output_video, fourcc, fps, (width, height))  # Output video writer

    # Set font scaling for text display based on video size
    base_scale = height / 500
    base_thickness = max(1, int(height / 300))
    count_scale = min(base_scale * 1.2, 2.0)  # Scale for shot count text
    count_thickness = base_thickness  # Thickness for shot count text
    angle_scale = base_scale * 0.6  # Scale for angle text
    angle_thickness = max(1, base_thickness - 1)  # Thickness for angle text
    count_y_pos = int(height / 10)  # Y-position for shot count display

    # Initialize variables for tracking shots and player data
    shot_count = 0  # Total number of shots detected
    frame_count = 0  # Current frame number
    left_knee_angles = defaultdict(lambda: deque(maxlen=int(fps / 3)))  # Store left knee angles
    right_knee_angles = defaultdict(lambda: deque(maxlen=int(fps / 3)))  # Store right knee angles
    last_shot_timestamps = {}  # Timestamps of last shot for each person
    last_shot_frames = {}  # Frame numbers of last shot for each person
    is_shooting = defaultdict(bool)  # Flag to track if a person is shooting
    shooting_frame_counts = defaultdict(int)  # Count consecutive shooting condition frames
    MIN_SHOOT_FRAMES = 2  # Minimum frames for a valid shot
    BALL_CONF_THRESHOLD = 0.4  # Confidence threshold for ball detection
    MIN_BALL_FOOT_DISTANCE = 50  # Min distance between ball and foot (pixels)
    MAX_BALL_FOOT_DISTANCE = 200  # Max distance between ball and foot (pixels)
    MIN_TIME_BETWEEN_SHOTS = 2  # Min time between shots (seconds)
    MIN_FRAMES_BETWEEN_SHOTS = int(fps * 2)  # Min frames between shots (2 seconds)
    BALL_DISTANCE_FRAMES = 5  # Frames to maintain valid ball-foot distance
    last_known_ball_position = None  # Last known position of the ball
    ball_position_buffer = deque(maxlen=10)  # Buffer for recent ball positions
    ball_foot_distances = defaultdict(lambda: deque(maxlen=BALL_DISTANCE_FRAMES))  # Track ball-foot distances
    frames_since_last_ball = float('inf')  # Frames since last ball detection

    while True:
        # Read the next frame from the video
        ret, frame = video_reader.read()
        if not ret:
            break  # Exit if no more frames

        # Get current time for timestamp comparisons
        current_time = datetime.datetime.now()

        # Detect poses using YOLO pose model
        pose_results = pose_detector(frame)
        annotated_frame = pose_results[0].plot()  # Get frame with pose annotations

        # Detect the ball using YOLO ball model
        ball_detected = False
        ball_results = ball_detector(frame)
        for box in ball_results[0].boxes:
            if int(box.cls) == 0 and float(box.conf) >= BALL_CONF_THRESHOLD:
                bbox = box.xyxy.cpu().numpy()[0]
                ball_center = np.array([(bbox[0] + bbox[2]) / 2, (bbox[1] + bbox[3]) / 2])  # Ball center
                ball_position_buffer.append(ball_center)
                last_known_ball_position = ball_center
                ball_detected = True
                frames_since_last_ball = 0
                # Draw a yellow rectangle around the ball
                cv2.rectangle(annotated_frame, (int(bbox[0]), int(bbox[1])),
                              (int(bbox[2]), int(bbox[3])), (0, 255, 255), 2)
                # Display ball confidence score
                cv2.putText(annotated_frame, f"Ball ({float(box.conf):.2f})",
                            (int(bbox[0]), int(bbox[1]) - 10), cv2.FONT_HERSHEY_SIMPLEX,
                            angle_scale, (0, 255, 255), angle_thickness)
        if not ball_detected:
            frames_since_last_ball += 1  # Increment frames since last ball detection

        # Use last known ball position if within 30 frames
        ball_position = last_known_ball_position if last_known_ball_position is not None and frames_since_last_ball < 30 else None

        # Analyze poses for each detected person
        if pose_results[0].keypoints is not None:
            keypoints = pose_results[0].keypoints.data.cpu().numpy()
            for person_idx, kps in enumerate(keypoints):
                if kps.shape[0] < 17:
                    continue  # Skip if not enough keypoints

                # Calculate knee angles (left: hip-knee-ankle, right: hip-knee-ankle)
                left_knee_angle = calculate_angle(kps[11, :2], kps[13, :2], kps[15, :2]) \
                    if all(kps[i, 2] > 0.3 for i in [11, 13, 15]) else None
                right_knee_angle = calculate_angle(kps[12, :2], kps[14, :2], kps[16, :2]) \
                    if all(kps[i, 2] > 0.3 for i in [12, 14, 16]) else None

                # Store knee angles for pattern analysis
                if left_knee_angle is not None:
                    left_knee_angles[person_idx].append(left_knee_angle)
                if right_knee_angle is not None:
                    right_knee_angles[person_idx].append(right_knee_angle)

                # Check distance between ball and support foot
                ball_distance_condition = False
                left_foot_ball_dist = float('inf')
                right_foot_ball_dist = float('inf')
                support_foot_dist = float('inf')
                if ball_position is not None:
                    if kps[15, 2] > 0.3:  # Left ankle confidence
                        left_foot_ball_dist = np.linalg.norm(ball_position - kps[15, :2])
                    if kps[16, 2] > 0.3:  # Right ankle confidence
                        right_foot_ball_dist = np.linalg.norm(ball_position - kps[16, :2])
                    support_foot_dist = min(left_foot_ball_dist, right_foot_ball_dist)
                    if MIN_BALL_FOOT_DISTANCE <= support_foot_dist <= MAX_BALL_FOOT_DISTANCE:
                        ball_foot_distances[person_idx].append(support_foot_dist)
                    else:
                        ball_foot_distances[person_idx].clear()
                    ball_distance_condition = len(ball_foot_distances[person_idx]) >= BALL_DISTANCE_FRAMES

                # Check knee angle patterns (indicates shooting motion)
                left_angle_pattern = False
                right_angle_pattern = False
                if len(left_knee_angles[person_idx]) >= 2:
                    angles = list(left_knee_angles[person_idx])
                    diffs = np.diff(angles)
                    for i in range(len(diffs) - 1):
                        if diffs[i] < -10 and diffs[i + 1] > 10:  # Decrease then increase
                            left_angle_pattern = True
                            break
                    if diffs[-1] > 15:  # Large increase in last frame
                        left_angle_pattern = True
                if len(right_knee_angles[person_idx]) >= 2:
                    angles = list(right_knee_angles[person_idx])
                    diffs = np.diff(angles)
                    for i in range(len(diffs) - 1):
                        if diffs[i] < -10 and diffs[i + 1] > 10:  # Decrease then increase
                            right_angle_pattern = True
                            break
                    if diffs[-1] > 15:  # Large increase in last frame
                        right_angle_pattern = True

                # Determine if shooting conditions are met
                left_shot_condition = left_angle_pattern and (ball_distance_condition or not ball_detected)
                right_shot_condition = right_angle_pattern and (ball_distance_condition or not ball_detected)
                shooting_condition = left_shot_condition or right_shot_condition

                # Check time and frame constraints to prevent double-counting
                can_shoot = True
                if person_idx in last_shot_frames:
                    frames_since_last_shot = frame_count - last_shot_frames[person_idx]
                    if frames_since_last_shot < MIN_FRAMES_BETWEEN_SHOTS:
                        can_shoot = False
                        shooting_frame_counts[person_idx] = 0

                if person_idx in last_shot_timestamps:
                    time_since_last_shot = (current_time - last_shot_timestamps[person_idx]).total_seconds()
                    if time_since_last_shot < MIN_TIME_BETWEEN_SHOTS:
                        can_shoot = False
                        shooting_frame_counts[person_idx] = 0

                # Count shots if conditions are met
                if shooting_condition:
                    shooting_frame_counts[person_idx] += 1
                else:
                    shooting_frame_counts[person_idx] = 0

                if (shooting_frame_counts[person_idx] >= MIN_SHOOT_FRAMES and
                    not is_shooting[person_idx] and can_shoot):
                    is_shooting[person_idx] = True
                    shot_count += 1
                    last_shot_timestamps[person_idx] = current_time
                    last_shot_frames[person_idx] = frame_count
                    shooting_frame_counts[person_idx] = 0

                if not shooting_condition:
                    is_shooting[person_idx] = False

                # Draw knee angles on the frame
                if left_knee_angle:
                    pt = tuple(kps[13, :2].astype(int))
                    cv2.putText(annotated_frame, f"LK:{left_knee_angle:.1f}", pt,
                                cv2.FONT_HERSHEY_SIMPLEX, angle_scale, (0, 255, 0), angle_thickness)
                if right_knee_angle:
                    pt = tuple(kps[14, :2].astype(int))
                    cv2.putText(annotated_frame, f"RK:{right_knee_angle:.1f}", pt,
                                cv2.FONT_HERSHEY_SIMPLEX, angle_scale, (0, 255, 0), angle_thickness)

        # Display the shot count on the frame
        cv2.putText(annotated_frame, f"Shoot Count: {shot_count}", (10, count_y_pos),
                    cv2.FONT_HERSHEY_SIMPLEX, count_scale, (0, 255, 0), count_thickness)

        # Write the annotated frame to the output video
        video_writer.write(annotated_frame)
        frame_count += 1

    # Release video resources
    video_reader.release()
    video_writer.release()

if __name__ == "__main__":
    # Define input and output directories
    input_dir = "/content/drive/MyDrive/Colab Notebooks/soccer_prj/soccer/soccer_input"
    output_dir = "/content/drive/MyDrive/Colab Notebooks/soccer_prj/soccer/soccer_output"
    os.makedirs(output_dir, exist_ok=True)  # Create output directory if it doesn't exist

    # Process all video files in the input directory
    video_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.mp4', '.avi', '.mov'))]
    for video_file in video_files:
        input_path = os.path.join(input_dir, video_file)
        output_path = os.path.join(output_dir, f"optimized_{video_file}")
        print(f"Starting processing for video: {input_path}")
        analyze_soccer_video(input_path, output_path)
        print(f"Finished processing for video: {input_path}")
# Out:
# Starting processing for video: /content/drive/MyDrive/Colab Notebooks/soccer_prj/soccer/soccer_input/real_video.mp4
#
# 0: 384x640 1 person, 3149.9ms
# Speed: 20.6ms preprocess, 3149.9ms inference, 31.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2546.5ms
# Speed: 5.2ms preprocess, 2546.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2609.6ms
# Speed: 5.0ms preprocess, 2609.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3587.0ms
# Speed: 4.3ms preprocess, 3587.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3229.2ms
# Speed: 13.2ms preprocess, 3229.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2477.2ms
# Speed: 4.2ms preprocess, 2477.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2595.4ms
# Speed: 5.1ms preprocess, 2595.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2478.8ms
# Speed: 4.3ms preprocess, 2478.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3600.8ms
# Speed: 5.1ms preprocess, 3600.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3241.5ms
# Speed: 5.1ms preprocess, 3241.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2586.5ms
# Speed: 5.2ms preprocess, 2586.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2477.9ms
# Speed: 4.2ms preprocess, 2477.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2563.5ms
# Speed: 5.1ms preprocess, 2563.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3293.5ms
# Speed: 4.1ms preprocess, 3293.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3511.7ms
# Speed: 9.1ms preprocess, 3511.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2736.4ms
# Speed: 4.2ms preprocess, 2736.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3393.5ms
# Speed: 4.5ms preprocess, 3393.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2486.9ms
# Speed: 4.0ms preprocess, 2486.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3910.2ms
# Speed: 5.0ms preprocess, 3910.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2891.3ms
# Speed: 8.1ms preprocess, 2891.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2614.6ms
# Speed: 5.0ms preprocess, 2614.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2484.0ms
# Speed: 4.2ms preprocess, 2484.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2592.1ms
# Speed: 5.5ms preprocess, 2592.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3612.4ms
# Speed: 4.6ms preprocess, 3612.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3188.6ms
# Speed: 11.4ms preprocess, 3188.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2481.1ms
# Speed: 4.3ms preprocess, 2481.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2590.7ms
# Speed: 6.2ms preprocess, 2590.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2498.7ms
# Speed: 4.5ms preprocess, 2498.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3624.0ms
# Speed: 5.3ms preprocess, 3624.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3193.3ms
# Speed: 5.2ms preprocess, 3193.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2618.5ms
# Speed: 6.2ms preprocess, 2618.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2486.9ms
# Speed: 4.8ms preprocess, 2486.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2601.4ms
# Speed: 5.0ms preprocess, 2601.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3407.7ms
# Speed: 4.2ms preprocess, 3407.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3424.3ms
# Speed: 5.1ms preprocess, 3424.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2735.3ms
# Speed: 4.3ms preprocess, 2735.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2584.6ms
# Speed: 5.1ms preprocess, 2584.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2532.6ms
# Speed: 4.3ms preprocess, 2532.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3525.6ms
# Speed: 4.7ms preprocess, 3525.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3289.2ms
# Speed: 4.8ms preprocess, 3289.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2617.4ms
# Speed: 4.8ms preprocess, 2617.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2472.8ms
# Speed: 4.6ms preprocess, 2472.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2608.3ms
# Speed: 9.6ms preprocess, 2608.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3264.6ms
# Speed: 4.5ms preprocess, 3264.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3568.3ms
# Speed: 8.4ms preprocess, 3568.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2501.5ms
# Speed: 3.8ms preprocess, 2501.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2583.4ms
# Speed: 4.5ms preprocess, 2583.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2483.2ms
# Speed: 4.3ms preprocess, 2483.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3317.4ms
# Speed: 5.0ms preprocess, 3317.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3470.3ms
# Speed: 4.9ms preprocess, 3470.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2568.9ms
# Speed: 5.0ms preprocess, 2568.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2507.4ms
# Speed: 4.2ms preprocess, 2507.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2584.1ms
# Speed: 4.7ms preprocess, 2584.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3064.1ms
# Speed: 5.6ms preprocess, 3064.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3755.7ms
# Speed: 7.7ms preprocess, 3755.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2505.2ms
# Speed: 4.1ms preprocess, 2505.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2614.2ms
# Speed: 4.7ms preprocess, 2614.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2508.6ms
# Speed: 4.2ms preprocess, 2508.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3103.1ms
# Speed: 5.0ms preprocess, 3103.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3736.4ms
# Speed: 5.5ms preprocess, 3736.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2584.4ms
# Speed: 5.2ms preprocess, 2584.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2519.2ms
# Speed: 4.4ms preprocess, 2519.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2584.9ms
# Speed: 5.0ms preprocess, 2584.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2817.1ms
# Speed: 4.2ms preprocess, 2817.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3987.7ms
# Speed: 8.7ms preprocess, 3987.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2500.5ms
# Speed: 4.7ms preprocess, 2500.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2568.6ms
# Speed: 5.1ms preprocess, 2568.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2500.2ms
# Speed: 4.6ms preprocess, 2500.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2812.3ms
# Speed: 4.8ms preprocess, 2812.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 3913.3ms
# Speed: 4.5ms preprocess, 3913.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2645.4ms
# Speed: 12.1ms preprocess, 2645.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2490.9ms
# Speed: 4.3ms preprocess, 2490.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2597.5ms
# Speed: 5.1ms preprocess, 2597.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 2550.9ms
# Speed: 5.0ms preprocess, 2550.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4090.5ms
# Speed: 10.9ms preprocess, 4090.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2652.5ms
# Speed: 5.0ms preprocess, 2652.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2594.4ms
# Speed: 4.9ms preprocess, 2594.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2489.3ms
# Speed: 4.1ms preprocess, 2489.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2626.8ms
# Speed: 5.1ms preprocess, 2626.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3923.0ms
# Speed: 4.5ms preprocess, 3923.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2849.5ms
# Speed: 11.9ms preprocess, 2849.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2492.6ms
# Speed: 4.5ms preprocess, 2492.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2593.1ms
# Speed: 5.1ms preprocess, 2593.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2495.8ms
# Speed: 4.4ms preprocess, 2495.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3988.2ms
# Speed: 4.9ms preprocess, 3988.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2810.9ms
# Speed: 4.7ms preprocess, 2810.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2587.5ms
# Speed: 5.7ms preprocess, 2587.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2469.3ms
# Speed: 4.7ms preprocess, 2469.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2611.1ms
# Speed: 4.5ms preprocess, 2611.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3732.9ms
# Speed: 4.3ms preprocess, 3732.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3082.7ms
# Speed: 5.2ms preprocess, 3082.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2513.7ms
# Speed: 4.3ms preprocess, 2513.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2597.7ms
# Speed: 4.9ms preprocess, 2597.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2486.1ms
# Speed: 4.2ms preprocess, 2486.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3799.4ms
# Speed: 6.6ms preprocess, 3799.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3039.8ms
# Speed: 4.6ms preprocess, 3039.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2567.9ms
# Speed: 4.5ms preprocess, 2567.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2497.0ms
# Speed: 3.7ms preprocess, 2497.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2594.5ms
# Speed: 4.5ms preprocess, 2594.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3486.2ms
# Speed: 4.4ms preprocess, 3486.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3374.9ms
# Speed: 4.7ms preprocess, 3374.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2499.0ms
# Speed: 4.7ms preprocess, 2499.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2616.8ms
# Speed: 6.4ms preprocess, 2616.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2476.7ms
# Speed: 4.6ms preprocess, 2476.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3496.8ms
# Speed: 8.5ms preprocess, 3496.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3316.9ms
# Speed: 5.9ms preprocess, 3316.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2563.0ms
# Speed: 5.1ms preprocess, 2563.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2489.8ms
# Speed: 4.7ms preprocess, 2489.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2586.7ms
# Speed: 11.0ms preprocess, 2586.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3210.8ms
# Speed: 4.3ms preprocess, 3210.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3560.5ms
# Speed: 6.1ms preprocess, 3560.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2489.0ms
# Speed: 4.2ms preprocess, 2489.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2549.7ms
# Speed: 5.1ms preprocess, 2549.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2506.6ms
# Speed: 4.7ms preprocess, 2506.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3156.9ms
# Speed: 4.7ms preprocess, 3156.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3625.4ms
# Speed: 8.3ms preprocess, 3625.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2593.0ms
# Speed: 8.3ms preprocess, 2593.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2477.7ms
# Speed: 4.4ms preprocess, 2477.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2573.5ms
# Speed: 4.9ms preprocess, 2573.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2886.3ms
# Speed: 6.8ms preprocess, 2886.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3944.5ms
# Speed: 5.9ms preprocess, 3944.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2462.0ms
# Speed: 4.6ms preprocess, 2462.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2603.8ms
# Speed: 6.0ms preprocess, 2603.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2503.9ms
# Speed: 4.9ms preprocess, 2503.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2850.0ms
# Speed: 4.6ms preprocess, 2850.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3889.1ms
# Speed: 5.1ms preprocess, 3889.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2622.4ms
# Speed: 5.5ms preprocess, 2622.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2494.9ms
# Speed: 4.1ms preprocess, 2494.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2563.2ms
# Speed: 5.0ms preprocess, 2563.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2520.2ms
# Speed: 4.5ms preprocess, 2520.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4047.7ms
# Speed: 4.9ms preprocess, 4047.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2665.7ms
# Speed: 4.6ms preprocess, 2665.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2578.3ms
# Speed: 4.6ms preprocess, 2578.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2514.9ms
# Speed: 4.4ms preprocess, 2514.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2581.4ms
# Speed: 5.4ms preprocess, 2581.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3861.9ms
# Speed: 4.3ms preprocess, 3861.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2934.0ms
# Speed: 4.8ms preprocess, 2934.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2464.5ms
# Speed: 4.0ms preprocess, 2464.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2587.1ms
# Speed: 4.7ms preprocess, 2587.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2480.8ms
# Speed: 5.0ms preprocess, 2480.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3870.7ms
# Speed: 4.6ms preprocess, 3870.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2989.8ms
# Speed: 4.9ms preprocess, 2989.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2577.8ms
# Speed: 4.5ms preprocess, 2577.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2466.5ms
# Speed: 4.6ms preprocess, 2466.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2606.2ms
# Speed: 4.7ms preprocess, 2606.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3511.2ms
# Speed: 4.4ms preprocess, 3511.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3260.1ms
# Speed: 6.2ms preprocess, 3260.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2490.3ms
# Speed: 4.1ms preprocess, 2490.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2577.3ms
# Speed: 4.9ms preprocess, 2577.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2473.1ms
# Speed: 4.7ms preprocess, 2473.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3467.7ms
# Speed: 5.0ms preprocess, 3467.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3312.1ms
# Speed: 6.1ms preprocess, 3312.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2593.2ms
# Speed: 5.1ms preprocess, 2593.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2444.5ms
# Speed: 4.5ms preprocess, 2444.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2585.2ms
# Speed: 4.6ms preprocess, 2585.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3122.5ms
# Speed: 4.4ms preprocess, 3122.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3680.2ms
# Speed: 12.9ms preprocess, 3680.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2463.0ms
# Speed: 4.6ms preprocess, 2463.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2576.6ms
# Speed: 4.6ms preprocess, 2576.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2482.9ms
# Speed: 4.5ms preprocess, 2482.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3149.4ms
# Speed: 4.7ms preprocess, 3149.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3645.6ms
# Speed: 4.7ms preprocess, 3645.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2573.7ms
# Speed: 5.0ms preprocess, 2573.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2513.9ms
# Speed: 4.5ms preprocess, 2513.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2602.6ms
# Speed: 5.8ms preprocess, 2602.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2862.9ms
# Speed: 5.2ms preprocess, 2862.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3895.9ms
# Speed: 9.4ms preprocess, 3895.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2484.8ms
# Speed: 7.8ms preprocess, 2484.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2573.6ms
# Speed: 6.1ms preprocess, 2573.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2487.1ms
# Speed: 4.6ms preprocess, 2487.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2843.9ms
# Speed: 5.2ms preprocess, 2843.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3910.0ms
# Speed: 5.8ms preprocess, 3910.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2897.9ms
# Speed: 5.7ms preprocess, 2897.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3457.4ms
# Speed: 4.6ms preprocess, 3457.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4074.6ms
# Speed: 9.2ms preprocess, 4074.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4024.9ms
# Speed: 5.2ms preprocess, 4024.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2722.2ms
# Speed: 5.0ms preprocess, 2722.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2488.1ms
# Speed: 3.9ms preprocess, 2488.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2564.8ms
# Speed: 5.2ms preprocess, 2564.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2489.9ms
# Speed: 4.7ms preprocess, 2489.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4134.2ms
# Speed: 4.7ms preprocess, 4134.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2721.5ms
# Speed: 4.9ms preprocess, 2721.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2603.0ms
# Speed: 5.0ms preprocess, 2603.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2484.9ms
# Speed: 4.6ms preprocess, 2484.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2625.1ms
# Speed: 5.8ms preprocess, 2625.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3761.7ms
# Speed: 4.8ms preprocess, 3761.7ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3002.9ms
# Speed: 5.2ms preprocess, 3002.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2486.7ms
# Speed: 4.7ms preprocess, 2486.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2587.2ms
# Speed: 6.4ms preprocess, 2587.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2474.3ms
# Speed: 4.6ms preprocess, 2474.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3783.2ms
# Speed: 4.7ms preprocess, 3783.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3047.3ms
# Speed: 5.5ms preprocess, 3047.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2567.9ms
# Speed: 5.0ms preprocess, 2567.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2475.8ms
# Speed: 4.8ms preprocess, 2475.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2589.6ms
# Speed: 4.9ms preprocess, 2589.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3544.8ms
# Speed: 6.7ms preprocess, 3544.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3301.1ms
# Speed: 12.1ms preprocess, 3301.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2472.6ms
# Speed: 4.7ms preprocess, 2472.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2606.2ms
# Speed: 7.4ms preprocess, 2606.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2475.4ms
# Speed: 4.6ms preprocess, 2475.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3529.7ms
# Speed: 6.5ms preprocess, 3529.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3316.9ms
# Speed: 7.6ms preprocess, 3316.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2586.0ms
# Speed: 4.9ms preprocess, 2586.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2486.8ms
# Speed: 4.5ms preprocess, 2486.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2614.3ms
# Speed: 5.1ms preprocess, 2614.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3277.9ms
# Speed: 4.6ms preprocess, 3277.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3563.1ms
# Speed: 8.0ms preprocess, 3563.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2505.1ms
# Speed: 5.0ms preprocess, 2505.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2600.8ms
# Speed: 4.7ms preprocess, 2600.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2501.6ms
# Speed: 4.6ms preprocess, 2501.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3264.2ms
# Speed: 4.6ms preprocess, 3264.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3579.6ms
# Speed: 4.9ms preprocess, 3579.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2621.0ms
# Speed: 4.8ms preprocess, 2621.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 2474.7ms
# Speed: 4.1ms preprocess, 2474.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2595.5ms
# Speed: 5.1ms preprocess, 2595.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 3022.8ms
# Speed: 4.4ms preprocess, 3022.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Finished processing for video: /content/drive/MyDrive/Colab Notebooks/soccer_prj/soccer/soccer_input/real_video.mp4
